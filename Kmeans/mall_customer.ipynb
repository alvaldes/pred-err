# %% [markdown]
# ### Sobre el dataset
# El dataset contiene la información básica (ID, edad, género, ingresos, puntaje de gasto) sobre los clientes de un centro comercial. El puntaje de gasto es algo que asigna al cliente en función de sus parámetros definidos como el comportamiento del cliente y los datos de compra.

# %%
import pandas as pd

df = pd.read_excel('Mall_Customers.xls')
df.head()
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_excel('Mall_Customers.xls', engine='xlrd')
#       4 df.head()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/mineria1/lib/python3.8/site-packages/pandas/io/excel/_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
# ...
